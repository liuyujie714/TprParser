# %%
import MDAnalysis as mda

# %%
u = mda.Universe('benchMEM.tpr', 'out.gro')
u.atoms.write('test.gro')
print(u.atoms.resids)
print(u.atoms.resinds)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\liuyujie714\AppData\Local\Programs\Python\Python38\lib\site-packages\MDAnalysis\core\universe.py:110, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     109     with parser(topology_file) as p:
# --> 110         topology = p.parse(**kwargs)
#     111 except (IOError, OSError) as err:
#     112     # There are 2 kinds of errors that might be raised here:
#     113     # one because the file isn't present
#     114     # or the permissions are bad, second when the parser fails
#
# File c:\Users\liuyujie714\AppData\Local\Programs\Python\Python38\lib\site-packages\MDAnalysis\topology\TPRParser.py:206, in TPRParser.parse(self, tpr_resid_from_one, **kwargs)
#     205 try:
# --> 206     th = tpr_utils.read_tpxheader(data)                    # tpxheader
#     207 except (EOFError, ValueError):
#
# ...
